# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.cluster as cls
from sklearn.neighbors import KNeighborsClassifier
import sklearn.model_selection as ms
import sklearn.metrics as mt

# %%
df = pd.read_csv("segmentation data.csv")

# %%
df
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0
#
# [2000 rows x 8 columns]

# %%
df.drop("ID", axis=1, inplace=True)

# %%
df
# Out:
#       Sex  Marital status  Age  Education  Income  Occupation  Settlement size
# 0       0               0   67          2  124670           1                2
# 1       1               1   22          1  150773           1                2
# 2       0               0   49          1   89210           0                0
# 3       0               0   45          1  171565           1                1
# 4       0               0   53          1  149031           1                1
# ...   ...             ...  ...        ...     ...         ...              ...
# 1995    1               0   47          1  123525           0                0
# 1996    1               1   27          1  117744           1                0
# 1997    0               0   31          0   86400           0                0
# 1998    1               1   24          1   97968           0                0
# 1999    0               0   25          0   68416           0                0
#
# [2000 rows x 7 columns]

# %%
x = df.drop("Income", axis=1)
y = df["Income"]

# %%
x_train, x_test, y_train, y_test = ms.train_test_split(x, y, test_size=0.2, random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(x_test)
y_pred
# Out:
# array([ 79353, 104263, 101616,  88559, 121466, 116844, 102133,  98573,
#        108678, 102974, 131021, 103387, 127928, 117005, 128271, 121347,
#         94324,  97474,  67619,  46865,  80232, 102781, 109700, 168904,
#         38247, 150158,  77472,  62263,  95171, 129798, 105240, 120499,
#         97856,  95171, 215150, 149022,  50947,  93648, 129425,  92542,
#         91925,  75297,  98517, 127928,  99012, 134112,  97474, 106120,
#        100195,  76057, 126531, 120426,  95911, 121400,  42516,  92281,
#        119307,  81609, 139547, 106215, 104754,  96145,  65815, 171804,
#         64037,  87494, 131242, 101616,  94324,  94655,  87494, 107508,
#         92498, 134102, 109324, 104235,  95639, 111394, 102133,  97741,
#        100794, 113212,  87058,  42516,  83660,  38247,  98573,  80987,
#        121400,  73913, 113108,  64105, 135765, 104355,  88141, 102974,
#         83660, 124214, 100644,  58258, 120354, 149022,  51882, 100892,
#        112347, 103521, 120131,  51791, 101616,  89374, 100794, 106446,
#        134102,  73703, 123109, 102974, 136638, 105240, 114476,  86015,
#         96062, 129838,  98032,  80987, 108838,  98573, 134794, 119307,
#         75626, 120131, 114588,  75100, 128639,  69609,  92498, 141858,
#         73266,  78489,  95911, 101157, 100892,  62335, 102374, 106515,
#        102974, 120354, 120426, 114476,  62689, 100794,  69609, 144657,
#        106215, 137000,  83687, 116021, 128053,  64037,  82414,  87801,
#         64105,  87537, 112458, 118101,  68468, 106446, 100644, 107276,
#         85115,  67619, 130344, 117729,  95911,  57480, 137000, 107142,
#         69375,  99012, 117272, 120426, 137000,  51791,  93148,  97306,
#        129838, 103387,  78489,  86015, 131021, 103577,  87801, 100215,
#         95911,  95639,  96062, 125351, 143723, 103577,  76057,  62335,
#         62689,  95911,  95445, 145896, 107408,  89374,  85402,  70431,
#        129838, 107301,  81394,  92020, 132145,  93634,  73703,  75626,
#        108278, 127147,  82414,  96769,  63506,  96062,  65815, 121400,
#         51791,  92498,  95445,  71702,  51496, 132950,  94962,  68468,
#         69114,  95911, 101270,  83660, 170387,  97474,  73266, 112458,
#        107780,  38247, 130164,  63506,  51882, 116540, 111394,  77720,
#        118408,  38247, 125119, 107158, 111394, 143734,  68790, 112486,
#         86015,  92351,  77317,  90500,  80987, 106120,  90719,  50947,
#        154344, 109324, 128234, 170387, 115494, 112486,  85974, 102000,
#        127928,  46865,  63506,  38247,  94655, 150158,  62335,  62335,
#         96614, 104235, 129640,  71167,  89374,  86015, 107099,  59127,
#         81743, 124214, 108678, 110040,  73266,  62335, 127752,  74666,
#        107408, 102974,  73703, 127147,  89210, 119307, 115892, 101157,
#         89534,  51681, 137231,  62335, 102374, 106205, 136886,  93148,
#        105055, 104755, 149410, 124902, 137069, 100644, 100644, 101616,
#         87058,  69609, 109499,  89210,  83660, 103470,  64105, 110291,
#        103521, 112347, 111858, 100511,  38247,  77317,  92366,  67408,
#         88800, 144657, 114476,  95445, 106446,  51882,  95445,  94356,
#         75626,  38247, 109700, 112458,  97558,  73913, 117005, 125883,
#         85974,  87537, 129798, 100215,  99012, 118677,  94655, 136671,
#        112227, 118677, 121400, 107780,  88559,  97115,  67619, 135090,
#        156495, 103521,  57480, 102000, 109188,  75100, 147259, 125351,
#         86015, 100737,  99012, 115809,  75536, 101210,  73913,  95171,
#         82298,  94711, 124214, 107408,  88800, 100511, 109700,  68389,
#        137000, 115403,  92020, 117729, 134112,  68389, 165717, 107158])

# %%
x_test
# Out:
#       Sex  Marital status  Age  Education  Occupation  Settlement size
# 1860    1               1   43          1           0                0
# 353     0               0   28          0           1                1
# 1333    1               1   48          2           0                0
# 905     0               0   20          0           2                2
# 1289    0               0   49          1           2                2
# ...   ...             ...  ...        ...         ...              ...
# 965     1               1   26          1           1                2
# 1284    0               1   35          1           1                1
# 1739    1               1   28          1           0                0
# 261     1               1   55          2           1                2
# 535     0               1   33          1           1                1
#
# [400 rows x 6 columns]
